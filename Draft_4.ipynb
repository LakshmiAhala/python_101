# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshmiAhala/python_101/blob/main/Draft_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # PART 1

def is_credit(my_list):
    
    nums = my_list.isnumeric()
    print("All of the characters entered are numbers:", nums)
    
    the_list = [int(x) for x in my_list]
    # print(the_list)
    
    total = 0

    the_list.reverse()
    # print('after reversing: ', the_list)
    
    for x in range(len(the_list)):
        n = the_list[x]
        if x % 2 == 0:
            total=total+n
        elif n >= 5:
            total = total + (2 * n - 9)
        else:
            total = total + (n * 2) 
        
    print("Total:", total)
    
    if total % 10 == 0:
        print("Valid Credit Card Number")   
    else:
        print("Invalid Credit Card Number")


# PART 2

def is_visa(the_list):
        
        length_1 = len(the_list)
        if length_1 == (16) and the_list[0] == 4:        
            return "Valid Visa Card Number" 
        else:
            return "Invalid Visa Number"       

        print(is_visa(the_list))
      


# PART 3


def is_mastercard(the_list):
        length_2 = len(the_list)
        if length_2 == 16 and the_list[0] == 5 and the_list[1] <= 5 and the_list[1] >= 0:
            return "Valid Mastercard Number"
        else:
            return "Invalid Mastercard Number"    
        
        print(is_mastercard(the_list))


def main():
  
    print("is_credit('6011000000000004')", is_credit("6011000000000004"))
    print()
    print("is_credit('79927398713')", is_credit("79927398713"))
    print()
    print("is_credit('30000000000004')" ,is_credit("30000000000004"))
    print()
    print("is_credit('6911600873502604')"  ,is_credit("6911600873502604"))
    print()
    print("is_credit('1234567890')",  is_credit("1234567890"))
    print()


    print("is_visa('6011000000000004')",is_visa("6011000000000004"))
    print()
    print("is_visa('79927398713')", is_visa("79927398713"))
    print()
    print("is_visa('30000000000004')" ,is_visa("30000000000004"))
    print()
    print("is_visa('6911600873502604')"  ,is_visa("6911600873502604"))
    print()
    print("is_visa('1234567890')",  is_visa("1234567890"))
    print()


    print("is_mastercard('6011000000000004')",is_mastercard("6011000000000004"))
    print()
    print("is_mastercard('79927398713')", is_mastercard("79927398713"))
    print()
    print("is_mastercard('30000000000004')" ,is_mastercard("30000000000004"))
    print()
    print("is_mastercard('6911600873502604')"  ,is_mastercard("6911600873502604"))
    print()
    print("is_mastercard('1234567890')",  is_mastercard("1234567890"))
    print()


# calling the main function

main()
# Out:
# All of the characters entered are numbers: True
# Total: 10
# Valid Credit Card Number
# is_credit('6011000000000004') None
#
# All of the characters entered are numbers: True
# Total: 70
# Valid Credit Card Number
# is_credit('79927398713') None
#
# All of the characters entered are numbers: True
# Total: 10
# Valid Credit Card Number
# is_credit('30000000000004') None
#
# All of the characters entered are numbers: True
# Total: 49
# Invalid Credit Card Number
# is_credit('6911600873502604') None
#
# All of the characters entered are numbers: True
# Total: 43
# Invalid Credit Card Number
# is_credit('1234567890') None
#
# is_visa('6011000000000004') Invalid Visa Number
#
# is_visa('79927398713') Invalid Visa Number
#
# is_visa('30000000000004') Invalid Visa Number
#
# is_visa('6911600873502604') Invalid Visa Number
#
# is_visa('1234567890') Invalid Visa Number
#
# is_mastercard('6011000000000004') Invalid Mastercard Number
#
# is_mastercard('79927398713') Invalid Mastercard Number
#
# is_mastercard('30000000000004') Invalid Mastercard Number
#
# is_mastercard('6911600873502604') Invalid Mastercard Number
#
# is_mastercard('1234567890') Invalid Mastercard Number
